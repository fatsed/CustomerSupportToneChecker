# %% [markdown]
# <a href="https://colab.research.google.com/github/fatsed/CustomerSupportToneChecker/blob/main/notebooks/01_build_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/fatsed/CustomerSupportToneChecker.git
# Out:
# Cloning into 'CustomerSupportToneChecker'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 33 (delta 11), reused 33 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (33/33), 6.20 KiB | 6.20 MiB/s, done.
# Resolving deltas: 100% (11/11), done.

# %%
# %cd /content/CustomerSupportToneChecker
# Out:
# /content/CustomerSupportToneChecker

# %%
# %cd notebooks
# Out:
# /content/CustomerSupportToneChecker/notebooks

# %%
import os
os.getcwd()
# Out:
# '/content/CustomerSupportToneChecker/notebooks'

# %%
import os
os.makedirs("../dataset", exist_ok=True)

# %%
import pandas as pd

data = [
    # Polite
    {"id": 1, "text": "سلام وقت بخیر. می‌خواستم وضعیت سفارش شماره ۱۲۳۴ رو بدونم.", "label": "polite"},
    {"id": 2, "text": "سلام و عرض ادب. لطفاً زمان تقریبی ارسال بسته منو اعلام کنید.", "label": "polite"},
    {"id": 3, "text": "با سلام. ممنون می‌شم اگر کد رهگیری را برای بنده ارسال کنید.", "label": "polite"},
    {"id": 4, "text": "روزتون بخیر. امکانش هست وضعیت مرسوله را بررسی کنید؟", "label": "polite"},
    {"id": 5, "text": "سلام. ممنون می‌شم اگر راهنمایی کنید چطور می‌تونم آدرس رو اصلاح کنم.", "label": "polite"},
    {"id": 6, "text": "وقتتون بخیر. اگر زحمتی نیست هزینه ارسال به شیراز رو می‌فرمایید؟", "label": "polite"},
    {"id": 7, "text": "سلام. مرسی از پشتیبانی خوبتون. فقط یک سوال درباره موجودی داشتم.", "label": "polite"},
    {"id": 8, "text": "سلام. لطفاً مشخصات فنی محصول رو برام ارسال می‌کنید؟", "label": "polite"},
    {"id": 9, "text": "درود بر شما. امکانش هست فاکتور خرید رو برام ایمیل کنید؟", "label": "polite"},
    {"id": 10, "text": "سلام و خسته نباشید. وضعیت سفارش من به‌روزرسانی نشده، ممکنه بررسی کنید؟", "label": "polite"},
    {"id": 11, "text": "سلام. اگر برای شما مقدوره، زمان دقیق ارسال رو اعلام کنید.", "label": "polite"},
    {"id": 12, "text": "روز بخیر. می‌خواستم مطمئن بشم سفارشم ثبت شده یا نه.", "label": "polite"},
    {"id": 13, "text": "سلام. ممنون می‌شم اگر لینک پرداخت رو دوباره ارسال کنید.", "label": "polite"},
    {"id": 14, "text": "سلام. آیا امکان تغییر سایز کالا وجود دارد؟", "label": "polite"},
    {"id": 15, "text": "وقت شما بخیر. اگر فرصت داشتید موجودی این کالا را بررسی کنید.", "label": "polite"},
    {"id": 16, "text": "سلام. من پیامم رو ارسال کردم، ممنون می‌شم اگر پیگیری کنید.", "label": "polite"},
    {"id": 17, "text": "سلام. اگر امکان داره، تخفیف‌های امروز رو اطلاع بدین.", "label": "polite"},
    {"id": 18, "text": "درود. لطفاً اگر ارسال انجام شد، اطلاع‌رسانی بفرمایید.", "label": "polite"},
    {"id": 19, "text": "سلام. من تازه ثبت‌نام کردم، ممنون می‌شم راهنمایی کنید.", "label": "polite"},
    {"id": 20, "text": "سلام. خیلی ممنون می‌شم اگر سفارشم رو سریع‌تر بررسی کنید.", "label": "polite"},
    {"id": 21, "text": "با سلام و احترام. آیا امکان تمدید گارانتی وجود دارد؟", "label": "polite"},
    {"id": 22, "text": "سلام. لطفاً رسید پرداخت را برای من ارسال کنید. سپاس.", "label": "polite"},
    {"id": 23, "text": "سلام. اگر ممکنه موجودی رنگ مشکی رو بررسی کنید.", "label": "polite"},
    {"id": 24, "text": "خسته نباشید. آیا ارسال با پست پیشتاز انجام می‌شود؟", "label": "polite"},
    {"id": 25, "text": "سلام وقت بخیر. برای انتخاب سایز مناسب راهنمایی می‌خواستم.", "label": "polite"},
    {"id": 26, "text": "سلام. لطفاً شماره تماس پشتیبانی را اعلام کنید.", "label": "polite"},
    {"id": 27, "text": "سلام. ممنون می‌شم اگر هزینه مرجوعی را بفرمایید.", "label": "polite"},
    {"id": 28, "text": "درود بر شما. امکان لغو سفارش وجود دارد؟", "label": "polite"},
    {"id": 29, "text": "سلام. خیلی ممنون می‌شم زمان تقریبی تحویل رو اعلام کنید.", "label": "polite"},
    {"id": 30, "text": "سلام. می‌خواستم بدونم امکان ارسال فوری هست؟", "label": "polite"},
    {"id": 31, "text": "سلام. ممنون از خدمات خوبتون. فقط یک سوال داشتم.", "label": "polite"},
    {"id": 32, "text": "وقت شما بخیر. امکان اصلاح شماره تماس وجود داره؟", "label": "polite"},
    {"id": 33, "text": "سلام. لطفاً اگر سفارشم ارسال شد اطلاع بدین.", "label": "polite"},
    {"id": 34, "text": "سلام. آیا این محصول شامل گارانتی هست؟", "label": "polite"},
    {"id": 35, "text": "بسیار ممنون می‌شم اگر راهنمایی کنید چطور ثبت‌نام کنم.", "label": "polite"},
    {"id": 36, "text": "سلام خدمت شما. امکان ارسال تصاویر واقعی محصول هست؟", "label": "polite"},
    {"id": 37, "text": "سلام. من سفارشم رو ثبت کردم، ممنون می‌شم تایید کنید.", "label": "polite"},
    {"id": 38, "text": "سلام. آیا امکان پرداخت در محل وجود دارد؟", "label": "polite"},
    {"id": 39, "text": "درود. لطفاً راهنمای خرید برای من ارسال کنید.", "label": "polite"},
    {"id": 40, "text": "سلام. ممنون اگر درباره تفاوت دو مدل توضیح بدین.", "label": "polite"},
    {"id": 41, "text": "سلام. هزینه ارسال برای چند محصول تغییر می‌کند؟", "label": "polite"},
    {"id": 42, "text": "روزتون بخیر. لطفاً زمان پاسخگویی تلفنی رو بفرمایید.", "label": "polite"},
    {"id": 43, "text": "سلام. امکانش هست لینک آموزش استفاده رو بفرستید؟", "label": "polite"},
    {"id": 44, "text": "سلام. آیا این محصول امکان تست دارد؟", "label": "polite"},
    {"id": 45, "text": "وقت بخیر. اگر زحمتی نیست اطلاعات فنی بیشتری می‌خواستم.", "label": "polite"},
    {"id": 46, "text": "سلام. ممنون می‌شم وضعیت انبار رو بررسی کنید.", "label": "polite"},
    {"id": 47, "text": "سلام و تشکر. فقط یک سوال کوچک درباره ارسال دارم.", "label": "polite"},
    {"id": 48, "text": "سلام. ممنون می‌شم اگر تخفیف‌های فعال رو معرفی کنید.", "label": "polite"},
    {"id": 49, "text": "سلام. آیا محصول دوباره موجود می‌شود؟", "label": "polite"},
    {"id": 50, "text": "سلام. از خدمات شما راضی هستم. یک سوال درباره مرجوعی داشتم.", "label": "polite"},
    {"id": 51, "text": "سلام وقت بخیر. می‌خواستم درباره روش ارسال بدونم.", "label": "polite"},
    {"id": 52, "text": "سلام. یه راهنمایی درباره شیوه پرداخت می‌خواستم.", "label": "polite"},
    {"id": 53, "text": "سلام دوستان. ممنون اگر پیگیری فرمایید سفارشم کجاست.", "label": "polite"},
    {"id": 54, "text": "سلام. این محصول برای استفاده روزمره مناسبه؟", "label": "polite"},
    {"id": 55, "text": "درود. لطفاً اگر موجود شد اطلاع بدید.", "label": "polite"},
    {"id": 56, "text": "سلام. می‌خواستم رنگ‌های موجود رو بدونم.", "label": "polite"},
    {"id": 57, "text": "سلام. امکان یادآوری زمان ارسال هست؟", "label": "polite"},
    {"id": 58, "text": "سلام. خیلی ممنون بابت پیگیری.", "label": "polite"},
    {"id": 59, "text": "وقتتون بخیر. ممنون می‌شم اگر راهنمای خرید بدید.", "label": "polite"},
    {"id": 60, "text": "سلام. یک سوال درباره فعال‌سازی گارانتی دارم.", "label": "polite"},
    {"id": 61, "text": "سلام. لطفاً لینک دانلود اپلیکیشن رو ارسال کنید.", "label": "polite"},
    {"id": 62, "text": "درود بر شما. ممنون از زحماتتون.", "label": "polite"},
    {"id": 63, "text": "سلام. فقط خواستم تشکر کنم بابت پشتیبانی خوبتون.", "label": "polite"},
    {"id": 64, "text": "سلام وقت بخیر. می‌خواستم یک سوال کوچک بپرسم.", "label": "polite"},
    {"id": 65, "text": "سلام. آیا امکان ارسال امروز هست؟", "label": "polite"},
    {"id": 66, "text": "سلام. می‌خواستم درباره شرایط بازگشت کالا بدونم.", "label": "polite"},
    {"id": 67, "text": "سلام. برای خرید عمده تخفیف دارید؟", "label": "polite"},
    {"id": 68, "text": "وقت بخیر. آیا امکان تست قبل از خرید وجود داره؟", "label": "polite"},
    {"id": 69, "text": "سلام. اگر ممکنه سایز‌بندی رو توضیح بدین.", "label": "polite"},
    {"id": 70, "text": "سلام. لطفاً اگر این محصول مشابه دارد اطلاع دهید.", "label": "polite"},
    {"id": 71, "text": "سلام. امکان داره سفارش رو سریع‌تر ارسال کنید؟ ممنون.", "label": "polite"},
    {"id": 72, "text": "سلام. من سفارشم ثبت شده ولی تایید نشده. ممکنه بررسی کنید؟", "label": "polite"},
    {"id": 73, "text": "سلام. آیا امکان ارسال به خارج از کشور وجود دارد؟", "label": "polite"},
    {"id": 74, "text": "سلام. ممنون از پاسخگویی شما.", "label": "polite"},
    {"id": 75, "text": "سلام. امکانش هست نمونه محصول بفرستید؟", "label": "polite"},
    {"id": 76, "text": "وقت شما بخیر. یک سوال درباره نحوه بسته‌بندی داشتم.", "label": "polite"},
    {"id": 77, "text": "سلام. کد تخفیف جدید دارید؟", "label": "polite"},
    {"id": 78, "text": "سلام. آیا این کالا اصل هست؟", "label": "polite"},
    {"id": 79, "text": "درود. لطفاً راهنمای نصب بفرستید.", "label": "polite"},
    {"id": 80, "text": "سلام. یک سوال درباره موجودی داشتم.", "label": "polite"},
    {"id": 81, "text": "سلام. لطفاً بسته من را دوباره بررسی کنید.", "label": "polite"},
    {"id": 82, "text": "سلام. چقدر زمان می‌بره تا ارسال بشه؟", "label": "polite"},
    {"id": 83, "text": "درود بر شما. آیا امکان ارسال فوری هست؟", "label": "polite"},
    {"id": 84, "text": "سلام. می‌خواستم کاتالوگ محصول رو ببینم.", "label": "polite"},
    {"id": 85, "text": "وقت بخیر. سفارش من کی آماده می‌شه؟", "label": "polite"},
    {"id": 86, "text": "سلام. نحوه استفاده از محصول چطور است؟", "label": "polite"},
    {"id": 87, "text": "سلام. لطفاً رسید سفارش رو ارسال کنید.", "label": "polite"},
    {"id": 88, "text": "سلام. محصولی مشابه این دارید؟", "label": "polite"},
    {"id": 89, "text": "سلام. خیلی ممنون بابت راهنمایی شما.", "label": "polite"},
    {"id": 90, "text": "سلام. ارسال در چه روزهایی انجام می‌شه؟", "label": "polite"},
    {"id": 91, "text": "سلام. فقط خواستم یک تشکر ساده بکنم.", "label": "polite"},
    {"id": 92, "text": "سلام. امکانش هست محصول رو رزرو کنم؟", "label": "polite"},
    {"id": 93, "text": "سلام. می‌خواستم زمان شروع ارسال‌ها رو بدونم.", "label": "polite"},
    {"id": 94, "text": "سلام. آیا امکان تمدید مهلت پرداخت هست؟", "label": "polite"},
    {"id": 95, "text": "وقت بخیر. موجودی انبار رو چک می‌کنید؟", "label": "polite"},
    {"id": 96, "text": "سلام. اگر ممکنه قبل ارسال اطلاع بدین.", "label": "polite"},
    {"id": 97, "text": "سلام. آیا امکان بسته‌بندی هدیه وجود دارد؟", "label": "polite"},
    {"id": 98, "text": "درود. لطفاً صورتحساب رو ارسال کنید.", "label": "polite"},
    {"id": 99, "text": "سلام. من اولین‌بارمه خرید می‌کنم، لطفاً راهنمایی کنید.", "label": "polite"},
    {"id": 100, "text": "سلام. ممنون از پاسخگوییتون، فقط یک سوال کوچک دارم.", "label": "polite"},
    #Semi polite
        {"id": 101, "text": "چرا هنوز سفارشم ارسال نشده؟ لطفاً رسیدگی کنید.", "label": "semi_polite"},
    {"id": 102, "text": "من چند روزه منتظر هستم ولی تغییری نمی‌بینم.", "label": "semi_polite"},
    {"id": 103, "text": "سفارشم دیر رسیده، می‌خوام بدونم مشکل چیه.", "label": "semi_polite"},
    {"id": 104, "text": "چند بار پیام دادم هنوز پاسخی نگرفتم.", "label": "semi_polite"},
    {"id": 105, "text": "این تأخیر برای من دردسر درست کرده، لطفاً بررسی کنید.", "label": "semi_polite"},
    {"id": 106, "text": "گفته بودید امروز ارسال می‌شه، ولی نشده هنوز.", "label": "semi_polite"},
    {"id": 107, "text": "فرایند ارسال خیلی طولانی شده، لطفاً توضیح بدید.", "label": "semi_polite"},
    {"id": 108, "text": "واقعاً انتظار داشتم سریع‌تر پیگیری کنید.", "label": "semi_polite"},
    {"id": 109, "text": "چرا وضعیت سفارش من ثابت مونده؟ نگران شدم.", "label": "semi_polite"},
    {"id": 110, "text": "محصولی که فرستادید با عکس فرق داره، باید چیکار کنم؟", "label": "semi_polite"},
    {"id": 111, "text": "این بار سومه که پیام می‌دم، ممنون می‌شم پیگیری کنید.", "label": "semi_polite"},
    {"id": 112, "text": "توضیحات محصول کامل نبود، لطفاً دقیق‌تر توضیح بدید.", "label": "semi_polite"},
    {"id": 113, "text": "سفارشم اشتباه ارسال شده، لطفاً اصلاح کنید.", "label": "semi_polite"},
    {"id": 114, "text": "این تاخیر برای کار من مشکل ایجاد کرده، لطفاً کمک کنید.", "label": "semi_polite"},
    {"id": 115, "text": "نمی‌دونم چرا اینقدر طول کشیده، لطفاً وضعیت رو چک کنید.", "label": "semi_polite"},
    {"id": 116, "text": "من روی زمان ارسال حساب کرده بودم، لطفاً پیگیری کنید.", "label": "semi_polite"},
    {"id": 117, "text": "سفارش من باید دیروز می‌رسید ولی نرسیده.", "label": "semi_polite"},
    {"id": 118, "text": "راستش انتظار داشتم اطلاعات دقیق‌تری بدید.", "label": "semi_polite"},
    {"id": 119, "text": "چرا ارسال به این اندازه طولانی شده؟", "label": "semi_polite"},
    {"id":":120", "text": "می‌شه لطفاً دقیق‌تر توضیح بدید مشکل ارسال چیه؟", "label": "semi_polite"},
    {"id": 121, "text": "من منتظر تماس پشتیبانی هستم ولی کسی تماس نگرفته.", "label": "semi_polite"},
    {"id": 122, "text": "پیش‌فاکتور اشتباهه، لطفاً اصلاحش کنید.", "label": "semi_polite"},
    {"id": 123, "text": "این موضوع داره طولانی می‌شه، لطفاً یک راه‌حل بدید.", "label": "semi_polite"},
    {"id": 124, "text": "گفته بودید موجوده ولی الان می‌گید موجود نیست.", "label": "semi_polite"},
    {"id": 125, "text": "منتظر پاسخم، لطفاً زودتر اطلاع بدید.", "label": "semi_polite"},
    {"id": 126, "text": "من به اطلاعات بیشتری نیاز دارم، لطفاً دقیق‌تر توضیح بدید.", "label": "semi_polite"},
    {"id": 127, "text": "عجیبه که اینقدر طول کشیده، لطفاً بررسی کنید.", "label": "semi_polite"},
    {"id": 128, "text": "جوابی که دادید کامل نبود، لطفاً بیشتر راهنمایی کنید.", "label": "semi_polite"},
    {"id": 129, "text": "محصول آسیب دیده رسیده، لطفاً بفرمایید چطور مرجوع کنم.", "label": "semi_polite"},
    {"id": 130, "text": "چرا شماره پشتیبانی جواب نمی‌ده؟", "label": "semi_polite"},
    {"id": 131, "text": "این مشکلی که پیش اومده باید سریع‌تر حل بشه لطفاً.", "label": "semi_polite"},
    {"id": 132, "text": "به‌نظرم باید روند پاسخ‌دهی سریع‌تر باشه.", "label": "semi_polite"},
    {"id": 133, "text": "این موضوع یکم طولانی شده، فکر نمی‌کردم اینطوری بشه.", "label": "semi_polite"},
    {"id": 134, "text": "لطفاً دقیق‌تر بگید چقدر باید صبر کنم.", "label": "semi_polite"},
    {"id": 135, "text": "این دفعه پاسخگویی خیلی کند بود، لطفاً رسیدگی کنید.", "label": "semi_polite"},
    {"id": 136, "text": "من عجله داشتم ولی ارسال هنوز انجام نشده.", "label": "semi_polite"},
    {"id": 137, "text": "محصولی که فرستادید با سفارش من هماهنگ نیست.", "label": "semi_polite"},
    {"id": 138, "text": "راستش کمی ناراحتم چون انتظار داشتم سریع‌تر رسیدگی کنید.", "label": "semi_polite"},
    {"id": 139, "text": "اگر این مشکل برطرف نشه برای من دردسر می‌شه.", "label": "semi_polite"},
    {"id": 140, "text": "لطفاً یک توضیح روشن درباره وضعیت سفارش بدید.", "label": "semi_polite"},
    {"id": 141, "text": "این بار دومه که اشتباه ارسال می‌کنید.", "label": "semi_polite"},
    {"id": 142, "text": "لطفاً مسیر ارسال رو دوباره بررسی کنید، ظاهراً اشتباهه.", "label": "semi_polite"},
    {"id": 143, "text": "یکم طول کشیده، ممنون می‌شم اگر سریع‌تر کنید.", "label": "semi_polite"},
    {"id": 144, "text": "توضیحات کامل نبود، لطفاً بیشتر توضیح بدین.", "label": "semi_polite"},
    {"id": 145, "text": "جوابی که دادید کافی نبود، لطفاً بیشتر راهنمایی کنید.", "label": "semi_polite"},
    {"id": 146, "text": "بی‌زحمت چک کنید چرا بسته من هنوز ارسال نشده.", "label": "semi_polite"},
    {"id": 147, "text": "اگر ممکنه گزارش دقیق‌تری بدید، ممنون.", "label": "semi_polite"},
    {"id": 148, "text": "محصول اشتباه ارسال شده، لطفاً راهنمایی کنید.", "label": "semi_polite"},
    {"id": 149, "text": "این تأخیر واقعا کلافه‌کننده شده، لطفاً توضیح بدید.", "label": "semi_polite"},
    {"id": 150, "text": "پاسخ شما کمی گنگ بود، لطفاً روشن‌تر توضیح بدید.", "label": "semi_polite"},
    {"id": 151, "text": "این بار پاسخ‌دهی کند شده. لطفاً رسیدگی کنید.", "label": "semi_polite"},
    {"id": 152, "text": "راستش فکر می‌کردم این موضوع ساده‌تر حل بشه.", "label": "semi_polite"},
    {"id": 153, "text": "اگر لطف کنید دقیق‌تر توضیح بدید متشکر می‌شم.", "label": "semi_polite"},
    {"id": 154, "text": "مشخص نیست بسته من الان کجاست. لطفاً بررسی کنید.", "label": "semi_polite"},
    {"id": 155, "text": "به نظر میاد خطایی در سیستم هست. لطفاً کنترل کنید.", "label": "semi_polite"},
    {"id": 156, "text": "نمی‌دونم چرا سفارش من لغو شده. لطفاً توضیح بدین.", "label": "semi_polite"},
    {"id": 157, "text": "بسته من باید زودتر می‌رسید، لطفاً بررسی فوری کنید.", "label": "semi_polite"},
    {"id": 158, "text": "چند ساعته منتظرم، هنوز پاسخی دریافت نکردم.", "label": "semi_polite"},
    {"id": 159, "text": "راستش این مشکل برام عجیب شده. لطفاً توضیح بدید.", "label": "semi_polite"},
    {"id": 160, "text": "محصولی که رسید کامل نیست. لطفاً رسیدگی کنید.", "label": "semi_polite"},
    {"id": 161, "text": "یکم دیر پاسخ دادید. لطفاً سریع‌تر باشید.", "label": "semi_polite"},
    {"id": 162, "text": "کیفیت بسته‌بندی مناسب نبود. لطفاً دقت بیشتری کنید.", "label": "semi_polite"},
    {"id": 163, "text": "این مشکل رو باید زودتر اطلاع می‌دادید لطفاً.", "label": "semi_polite"},
    {"id": 164,"text": "اگر وضعیت سفارش مشخص نیست لطفاً بفرمایید.", "label": "semi_polite"},
    {"id": 165, "text": "امیدوارم هرچه زودتر پاسخ بدید چون عجله دارم.", "label": "semi_polite"},
    {"id": 166, "text": "بهتر بود زودتر اطلاع‌رسانی می‌کردید.", "label": "semi_polite"},
    {"id": 167, "text": "به نظر می‌رسه تأخیری در روند وجود داره. لطفاً بررسی کنید.", "label": "semi_polite"},
    {"id": 168, "text": "محصول به درستی مونتاژ نشده. لطفاً راهنمایی کنید.", "label": "semi_polite"},
    {"id": 169, "text": "لطفاً دقیق‌تر توضیح بدید که مشکل از کجاست.", "label": "semi_polite"},
    {"id": 170, "text": "می‌شه لطفاً بگید بسته الان کجاست؟", "label": "semi_polite"},
    {"id": 171, "text": "این موضوع داره طولانی می‌شه. لطفاً بررسی فوری کنید.", "label": "semi_polite"},
    {"id": 172, "text": "بسته من اشتباهی به شهر دیگه رفته. لطفاً اصلاح کنید.", "label": "semi_polite"},
    {"id": 173, "text": "من هنوز پیام تأیید دریافت نکردم. لطفاً ارسال کنید.", "label": "semi_polite"},
    {"id": 174, "text": "لطفاً سریع‌تر توضیح بدید مشکل دقیقاً چیه.", "label": "semi_polite"},
    {"id": 175, "text": "این موضوع باید ساده حل می‌شد، لطفاً پیگیری کنید.", "label": "semi_polite"},
    {"id": 176, "text": "بسته من هنوز اسکن نشده. لطفاً چک کنید.", "label": "semi_polite"},
    {"id": 177, "text": "اگر امکان داره یک توضیح کامل‌تر بدید.", "label": "semi_polite"},
    {"id": 178, "text": "تفاوت قیمت روی سایت و فاکتور وجود داره. لطفاً اصلاح کنید.", "label": "semi_polite"},
    {"id": 179, "text": "راستش انتظار پاسخ سریع‌تر رو داشتم.", "label": "semi_polite"},
    {"id": 180, "text": "اگر ممکنه زمان دقیق ارسال رو اعلام کنید.", "label": "semi_polite"},
    {"id": 181, "text": "برام مهمه بدونم بسته کی می‌رسه. لطفاً چک کنید.", "label": "semi_polite"},
    {"id": 182, "text": "این مشکل چند روزه ادامه داره. لطفاً رسیدگی کنید.", "label": "semi_polite"},
    {"id": 183, "text": "من چند بار پیام گذاشتم ولی پاسخی نگرفتم.", "label": "semi_polite"},
    {"id": 184, "text": "اگر پیام منو دیدید لطفاً پاسخ بدید.", "label": "semi_polite"},
    {"id": 185, "text": "سفارشم ناقص رسیده. لطفاً بررسی کنید.", "label": "semi_polite"},
    {"id": 186, "text": "لطفاً بگید چرا ارسال انجام نشده.", "label": "semi_polite"},
    {"id": 187, "text": "پاسختون دیر رسید، لطفاً در آینده سریع‌تر باشید.", "label": "semi_polite"},
    {"id": 188, "text": "این مشکل اگر ادامه پیدا کنه اذیت‌کننده می‌شه.", "label": "semi_polite"},
    {"id": 189, "text": "اگر وقت دارید این موضوع رو پیگیری کنید.", "label": "semi_polite"},
    {"id": 190, "text": "بسته من هنوز حرکت نکرده. لطفاً بررسی کنید.", "label": "semi_polite"},
    {"id": 191, "text": "ممنون می‌شم اگر آدرس صحیح رو تأیید کنید.", "label": "semi_polite"},
    {"id": 192, "text": "لطفاً پاسخ بدید چون این موضوع برام مهمه.", "label": "semi_polite"},
    {"id": 193, "text": "می‌تونید بگید چرا محصول تأخیر خورده؟", "label": "semi_polite"},
    {"id": 194, "text": "به نظر میاد بسته من گم شده. لطفاً بررسی کنید.", "label": "semi_polite"},
    {"id": 195, "text": "جواب قبلی شما کافی نبود، لطفاً بهتر توضیح بدید.", "label": "semi_polite"},
    {"id": 196, "text": "اگر ممکنه راهنمایی کنید چطور لغو کنم.", "label": "semi_polite"},
    {"id": 197, "text": "یکم بیشتر توضیح بدید لطفاً. ممنون.", "label": "semi_polite"},
    {"id": 198, "text": "این روند ارسال طولانی شده. لطفاً بررسی کنید.", "label": "semi_polite"},
    {"id": 199, "text": "محصولی که رسید بسته‌بندی ضعیفی داشت.", "label": "semi_polite"},
    {"id": 200, "text": "اگر امکانش هست یک آپدیت بدید درباره وضعیت بسته.", "label": "semi_polite"},
    #impolite
        {"id": 201, "text": "این چه وضعشه؟ بسته من چرا اینقدر دیر رسید؟", "label": "impolite"},
    {"id": 202, "text": "چرا هیچکس جواب درست نمی‌ده؟ واقعاً عجیبه!", "label": "impolite"},
    {"id": 203, "text": "محصول خراب به دستم رسیده. این چه کیفیتیه؟", "label": "impolite"},
    {"id": 204, "text": "چرا باید برای یک کار ساده اینقدر منتظر بمونم؟", "label": "impolite"},
    {"id": 205, "text": "پشتیبانی‌تون اصلاً درست کار نمی‌کنه!", "label": "impolite"},
    {"id": 206, "text": "چرا سفارش منو گم کردید؟ واقعاً غیرقابل قبوله.", "label": "impolite"},
    {"id": 207, "text": "این همه تأخیر برای چیه؟ توضیح بدید لطفاً!", "label": "impolite"},
    {"id": 208, "text": "جواب‌هاتون نصفه‌نیمه‌ست. لطفاً درست توضیح بدید.", "label": "impolite"},
    {"id": 209, "text": "چرا همیشه مشکل دارید؟ واقعاً خسته‌کننده‌ست.", "label": "impolite"},
    {"id": 210, "text": "محصول اصلاً اون چیزی که گفتید نبود.", "label": "impolite"},
    {"id": 211, "text": "چرا شماره پشتیبانی همیشه اشغاله؟ مگه چند نفر تماس می‌گیرن؟", "label": "impolite"},
    {"id": 212, "text": "این همه انتظار برای چی؟ واقعاً غیرعادیه.", "label": "impolite"},
    {"id": 213, "text": "بسته من کاملاً له شده رسیده. این چه وضع بسته‌بندیه؟", "label": "impolite"},
    {"id": 214, "text": "محصول اشتباه فرستادید! چطور همچین اشتباهی می‌کنید؟", "label": "impolite"},
    {"id": 215, "text": "چرا کسی پاسخگو نیست؟ این چه نوع پشتیبانیه؟", "label": "impolite"},
    {"id": 216, "text": "همیشه باید دنبالتون بیام تا یه کار انجام بدید؟", "label": "impolite"},
    {"id": 217, "text": "محصول داخل جعبه ناقصه! واقعاً مسخره‌ست.", "label": "impolite"},
    {"id": 218, "text": "این همه تأخیر فقط بی‌نظمی شما رو نشون می‌ده.", "label": "impolite"},
    {"id": 219, "text": "چرا باید سه روز صبر کنم تا جواب بدید؟", "label": "impolite"},
    {"id": 220, "text": "اگر نمی‌تونید سفارش‌ها رو مدیریت کنید چرا فروش دارید؟", "label": "impolite"},
    {"id": 221, "text": "این رفتار اصلاً حرفه‌ای نیست.", "label": "impolite"},
    {"id": 222, "text": "محصولی که فرستادید تقلبیه. این واقعاً قابل قبوله؟", "label": "impolite"},
    {"id": 223, "text": "چرا اطلاعات اشتباه روی سایت گذاشتید؟", "label": "impolite"},
    {"id": 224, "text": "بسته به آدرس اشتباه ارسال شده! واقعاً جدی؟", "label": "impolite"},
    {"id": 225, "text": "این وضعیت افتضاحه. لطفاً اصلاحش کنید.", "label": "impolite"},
    {"id": 226, "text": "چطور ممکنه سفارشم بدون هماهنگی لغو شده باشه؟", "label": "impolite"},
    {"id": 227, "text": "این چه نوع خدماتیه واقعاً؟", "label": "impolite"},
    {"id": 228, "text": "نمی‌دونم واقعاً با چه روشی کار می‌کنید.", "label": "impolite"},
    {"id": 229, "text": "چرا بسته من چند روزه تو یک مکان ثابت مونده؟", "label": "impolite"},
    {"id": 230, "text": "این همه تأخیر یعنی چی؟ توضیح بدید.", "label": "impolite"},
    {"id": 231, "text": "کیفیت محصول خیلی پایین‌تر از چیزی بود که گفته بودید.", "label": "impolite"},
    {"id": 232, "text": "به نظرم اصلاً به پیام‌های مشتری دقت نمی‌کنید.", "label": "impolite"},
    {"id": 233, "text": "چرا اینقدر نامنظم هستید؟", "label": "impolite"},
    {"id": 234, "text": "با این روند، آدم از خرید پشیمون می‌شه!", "label": "impolite"},
    {"id": 235, "text": "بسته من نرسیده، چرا می‌گید تحویل شده؟", "label": "impolite"},
    {"id": 236, "text": "این وضعیت واقعاً آزاردهنده‌ست.", "label": "impolite"},
    {"id": 237, "text": "چرا اطلاعات اشتباه ثبت کردید؟", "label": "impolite"},
    {"id": 238, "text": "محصول کاملاً فرق داشت. انگار اشتباهی چیزی فرستادید.", "label": "impolite"},
    {"id": 239, "text": "این همه بی‌دقتی واقعاً عجیبه.", "label": "impolite"},
    {"id": 240, "text": "محصول شکستۀ به دستم رسید. این چه وضعشه؟", "label": "impolite"},
    {"id": 241, "text": "چطور اینقدر ساده اشتباه می‌کنید؟", "label": "impolite"},
    {"id": 242, "text": "دفعه آخرمه از شما خرید می‌کنم.", "label": "impolite"},
    {"id": 243, "text": "پاسخ‌هاتون هیچ کمکی نمی‌کنه.", "label": "impolite"},
    {"id": 244, "text": "چرا فاکتور اشتباه صادر کردید؟", "label": "impolite"},
    {"id": 245, "text": "نمی‌دونم واقعاً دارید چه کار می‌کنید.", "label": "impolite"},
    {"id": 246, "text": "سفارشم به آدرس همسایه رفته! این چه کاریه؟", "label": "impolite"},
    {"id": 247, "text": "چرا بسته‌بندی اینقدر بی‌کیفیت بود؟", "label": "impolite"},
    {"id": 248, "text": "محصول کار نمی‌کنه! یعنی تستش نکردید؟", "label": "impolite"},
    {"id": 249, "text": "واقعا باید این همه دردسر بکشم؟", "label": "impolite"},
    {"id": 250, "text": "جواب‌ها خیلی دیر می‌رسه. این طوری نمی‌شه!", "label": "impolite"},
    {"id": 251, "text": "به نظرم این شرکت اصلاً درست مدیریت نمی‌شه.", "label": "impolite"},
    {"id": 252, "text": "این سطح پاسخگویی اصلاً قابل قبول نیست.", "label": "impolite"},
    {"id": 253, "text": "محصول اشتباهی ارسال کردید. چطور؟", "label": "impolite"},
    {"id": 254, "text": "این کارتون اصلاً حرفه‌ای نیست.", "label": "impolite"},
    {"id": 255, "text": "چرا بسته انقدر دیر تحویل داده شد؟", "label": "impolite"},
    {"id": 256, "text": "سفارشم گم شده؟ چون هیچ آپدیتی نمی‌ده!", "label": "impolite"},
    {"id": 257, "text": "محصول رو اشتباه تحویل گرفتید. رسیدگی کنید!", "label": "impolite"},
    {"id": 258, "text": "این همه اشتباه یعنی چی؟", "label": "impolite"},
    {"id": 259, "text": "تا کی باید صبر کنم؟ این درست نیست.", "label": "impolite"},
    {"id": 260, "text": "جواب‌هاتون ضد و نقیضه.", "label": "impolite"},
    {"id": 261, "text": "بسته من برگشت خورده بدون دلیل!", "label": "impolite"},
    {"id": 262, "text": "این رویکردتون اصلاً منطقی نیست.", "label": "impolite"},
    {"id": 263, "text": "چرا سفارش من رو اشتباه ثبت کردید؟", "label": "impolite"},
    {"id": 264, "text": "محصول نیمه‌کاره به دستم رسیده!", "label": "impolite"},
    {"id": 265, "text": "کیفیت محصول اصلاً شبیه عکس نیست.", "label": "impolite"},
    {"id": 266, "text": "این چه سرویسیه واقعاً؟", "label": "impolite"},
    {"id": 267, "text": "دوباره اشتباه کردید. واقعاً عجیبه.", "label": "impolite"},
    {"id": 268, "text": "چرا اینقدر کم‌توجه هستید؟", "label": "impolite"},
    {"id": 269, "text": "محصول بدون لوازم جانبی ارسال شده!", "label": "impolite"},
    {"id": 270, "text": "این جور ارسال کردن غیر قابل قبوله.", "label": "impolite"},
    {"id": 271, "text": "پاسخ‌هاتون خیلی سطحیه. لطفاً دقیق باشید.", "label": "impolite"},
    {"id": 272, "text": "سفارشم به‌طور عجیب لغو شده. چرا؟", "label": "impolite"},
    {"id": 273, "text": "اگر نمی‌تونید انجام بدید چرا قول می‌دید؟", "label": "impolite"},
    {"id": 274, "text": "بسته به درستی بسته‌بندی نشده بود.", "label": "impolite"},
    {"id": 275, "text": "این حجم خطا پذیرفتنی نیست.", "label": "impolite"},
    {"id": 276, "text": "ارسال اشتباهی باعث شده کارم عقب بیفته.", "label": "impolite"},
    {"id": 277, "text": "چرا باید خودم دائم پیگیری کنم؟", "label": "impolite"},
    {"id": 278, "text": "این روند ارسال واقعاً کند و آزاردهنده‌ست.", "label": "impolite"},
    {"id": 279, "text": "محصول فیک فرستادید؟ این چه وضعیه؟", "label": "impolite"},
    {"id": 280, "text": "چرا اصلاً پیام‌ها رو نمی‌خونید؟", "label": "impolite"},
    {"id": 281, "text": "این پاسخ‌ها هیچ کمکی به من نمی‌کنه.", "label": "impolite"},
    {"id": 282, "text": "محصول داخل جعبه خیس بود، واقعاً چرا؟", "label": "impolite"},
    {"id": 283, "text": "این اشتباهات پشت سر هم اعصاب خردکنه.", "label": "impolite"},
    {"id": 284, "text": "اصلاً انتظاری ازتون ندارم با این عملکرد.", "label": "impolite"},
    {"id": 285, "text": "این برخورد حرفه‌ای نیست.", "label": "impolite"},
    {"id": 286, "text": "تا کی باید صبر کنم برای یک جواب ساده؟", "label": "impolite"},
    {"id": 287, "text": "محصول باز شده و استفاده شده به دستم رسید!", "label": "impolite"},
    {"id": 288, "text": "این بسته‌تون اصلاً سالم نیست.", "label": "impolite"},
    {"id": 289, "text": "چرا بسته من برگشت خورده؟ هیچ توضیحی ندادید.", "label": "impolite"},
    {"id": 290, "text": "وضوح اطلاعاتتون خیلی ضعیفه.", "label": "impolite"},
    {"id": 291, "text": "پاسخ‌هاتون خیلی غیرمسئولانه‌ست.", "label": "impolite"},
    {"id": 292, "text": "کی قرار بود پیگیری کنید؟ هیچ کاری نکردید.", "label": "impolite"},
    {"id": 293, "text": "بسته من کجاست؟ این غیرقابل قبوله.", "label": "impolite"},
    {"id": 294, "text": "این روند واقعاً ناامیدکننده‌ست.", "label": "impolite"},
    {"id": 295, "text": "چرا اطلاعات نادرست به من دادید؟", "label": "impolite"},
    {"id": 296, "text": "این نحوه رفتار با مشتری اصلاً درست نیست.", "label": "impolite"},
    {"id": 297, "text": "محصولی که فرستادید کار نمی‌کنه. توضیح بدید.", "label": "impolite"},
    {"id": 298, "text": "این حجم بی‌نظمی رو تا حالا ندیده بودم.", "label": "impolite"},
    {"id": 299, "text": "متأسفم ولی کارتون اصلاً قابل قبول نیست.", "label": "impolite"},
    {"id": 300, "text": "بسته هنوز ارسال نشده. این رفتار اصلاً درست نیست.", "label": "impolite"},
]

df = pd.DataFrame(data)

csv_path = "../dataset/tone_dataset.csv"
df.to_csv(csv_path, index=False, encoding="utf-8-sig")
print("CSV saved successfully at:", csv_path)
print("Total rows:", len(df))
print(df.head())
# Out:
# CSV saved successfully at: ../dataset/tone_dataset.csv
# Total rows: 300
#   id                                               text   label
# 0  1  سلام وقت بخیر. می‌خواستم وضعیت سفارش شماره ۱۲۳...  polite
# 1  2  سلام و عرض ادب. لطفاً زمان تقریبی ارسال بسته م...  polite
# 2  3  با سلام. ممنون می‌شم اگر کد رهگیری را برای بند...  polite
# 3  4  روزتون بخیر. امکانش هست وضعیت مرسوله را بررسی ...  polite
# 4  5  سلام. ممنون می‌شم اگر راهنمایی کنید چطور می‌تو...  polite
